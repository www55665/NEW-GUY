# 學生21   65  100   50  53   98
# 學生22   82   66   74  62   56
# 學生23   89   84   60  76   68
# 學生24   60   63   81  90   88
# 學生25   81   68   83  54   89
# 學生26   99   70   98  79   52
# 學生27   99   80   59  85   78
# 學生28   71   60   60  79   86
# 學生29   86   66   85  88   54
# 學生30   50   92   52  88   64
# 學生31   89   86   55  73   73
# 學生32   95   91   90  64  100
# 學生33   53   88   93  89   55
# 學生34   86   96   72  66   72
# 學生35   75   69   72  78   63
# 學生36   54   85   64  96   93
# 學生37   58   75   81  99   63
# 學生38   67   87   98  60   78
# 學生39   61   62   61  52   63
# 學生40   50   75   93  71   63
# 學生41   80   79   94  67   99
# 學生42   89   95   61  99   50
# 學生43   63   58   67  68   67
# 學生44  100   93   76  97   77
# 學生45   83   99   67  94   54
# 學生46   79   50   55  71   98
# 學生47   88   75   93  80   82
# 學生48   77   60   82  88   53
# 學生49   77   61   61  96   99
# 學生50   59   58  100  54   97

# %%
s = df1.loc['學生1']
less_than_60_series = s[s<60]
#取出不及格的科目
failing_subjects = less_than_60_series.index.tolist()
failing_subjects
#取出不及格科目的分數
failing_scores = less_than_60_series.tolist()
failing_scores
#建立一個Series,值要轉換為字串,如果有多個值則用逗號分隔
failing_scores_str = ','.join(map(str, failing_scores))
failing_subjects_str = ','.join(failing_subjects)
pd.Series([failing_scores_str, failing_subjects_str], index=['分數', '不及格科目'])
# Out:
# 分數       55,51
# 不及格科目    國文,社會
# dtype: object

# %%
def apply_statistics(s):
    less_than_60_series = s[s<60]
    #不及格科目數量
    failing_subjects_count = less_than_60_series.count()
    #取出不及格的科目
    failing_subjects = less_than_60_series.index.tolist()
    
    #取出不及格科目的分數
    failing_scores = less_than_60_series.tolist()
    
    #建立一個Series,值要轉換為字串,如果有多個值則用逗號分隔
    failing_scores_str = ','.join(map(str, failing_scores))
    failing_subjects_str = ','.join(failing_subjects)
    return pd.Series([failing_subjects_count,failing_subjects_str,failing_scores_str], index=['不及格科目數量', '不及格科目', '分數'])


df2 = df1.apply(apply_statistics, axis=1)
df2
# Out:
#       不及格科目數量     不及格科目        分數
# 學生
# 學生1         2     國文,社會     55,51
# 學生2         1        國文        59
# 學生3         0
# 學生4         1        國文        55
# 學生5         0
# 學生6         1        自然        57
# 學生7         1        社會        50
# 學生8         0
# 學生9         2     英文,數學     54,52
# 學生10        1        英文        58
# 學生11        0
# 學生12        2     國文,數學     59,56
# 學生13        0
# 學生14        0
# 學生15        0
# 學生16        1        數學        52
# 學生17        1        社會        54
# 學生18        1        英文        50
# 學生19        2     國文,社會     51,52
# 學生20        1        數學        57
# 學生21        2     數學,自然     50,53
# 學生22        1        社會        56
# 學生23        0
# 學生24        0
# 學生25        1        自然        54
# 學生26        1        社會        52
# 學生27        1        數學        59
# 學生28        0
# 學生29        1        社會        54
# 學生30        2     國文,數學     50,52
# 學生31        1        數學        55
# 學生32        0
# 學生33        2     國文,社會     53,55
# 學生34        0
# 學生35        0
# 學生36        1        國文        54
# 學生37        1        國文        58
# 學生38        0
# 學生39        1        自然        52
# 學生40        1        國文        50
# 學生41        0
# 學生42        1        社會        50
# 學生43        1        英文        58
# 學生44        0
# 學生45        1        社會        54
# 學生46        2     英文,數學     50,55
# 學生47        0
# 學生48        1        社會        53
# 學生49        0
# 學生50        3  國文,英文,自然  59,58,54

# %%
#df要和df2合併
df_merged = pd.concat([df, df2], axis=1)
df_merged
# Out:

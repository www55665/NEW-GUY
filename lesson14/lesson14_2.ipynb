# %%
#載入字型
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont('ChineseFont.ttf')  # 字型檔路徑
mpl.rc('font', family='ChineseFont')

# %%
import matplotlib.pyplot as plt
# 來源資料
student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}
subjects = list(student1.keys())
scores1 = list(student1.values())
scores2 = list(student2.values())
print(scores1, scores2)

# 建立圖形和軸
figure = plt.figure(figsize=(8, 4), dpi=100, facecolor='w', edgecolor='k')
axes = figure.add_subplot(111)
axes.plot(subjects, scores1, label='學生1', marker='o', color='blue')
axes.plot(subjects, scores2, label='學生2', marker='o', color='red')
axes.set_title('學生成績比較', fontsize=16)#圖表標題
axes.set_xlabel('科目', fontsize=14)#X軸的標題
axes.set_ylabel('分數', fontsize=14)#Y軸的標題

#顯示背景網格
axes.grid(True, linestyle='--', alpha=1,axis='y')#(啟用背景網格,格式虛線,不透明度,僅顯示y軸虛線)

#顯示圖標註解
axes.legend(loc='best', fontsize=10,edgecolor='red', facecolor='gray')#圖標註解(系統判斷最佳位置,圖標大小,圖標框顏色,圖標背景色)

#marker上顯示學生分數
for i, score in enumerate(scores1):
    axes.text(subjects[i], score + 1, str(score), ha='center', va='bottom', fontsize=10, color='blue')
for i, score in enumerate(scores2):
    axes.text(subjects[i], score + 1, str(score), ha='center', va='bottom', fontsize=10, color='red')
    #(x軸對齊,y軸位置+1以避免重疊,顯示文字為字串,水平對齊為置中,垂直對齊下方文字,字體大小,文字顏色)

# marker上顯示學生分數,超過圖形範圍,將圖形範圍調整
# 設定y軸範圍(使用原有的最大值和最小值,各增加5)
axes.set_ylim(min(min(scores1), min(scores2)) - 5, max(max(scores1), max(scores2)) + 10)
#設定y軸範圍(挑選最小值(scores1中的最小值),(scores2中的最小值))然後-5的範圍
#設定y軸範圍(挑選最大值(scores1中的最大值),(scores2中的最大值))然後+10的範圍
plt.tight_layout()
#根據目前圖表中的內容，自動調整版面配置，使每個元素都有足夠的空間顯示，避免擠在一起或被擋住。

plt.show()
# Out:
# [78, 80, 92, 75, 85] [90, 75, 98, 65, 75]

# %%
import matplotlib.pyplot as plt
# 來源資料
student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}
subjects = list(student1.keys())
scores1 = list(student1.values())
scores2 = list(student2.values())
print(scores1, scores2)

# 建立圖形和軸
figure = plt.figure(figsize=(8, 4), dpi=100, facecolor='w', edgecolor='k')
axes = figure.add_subplot(111)
axes.plot(subjects, scores1, label='學生1', marker='o', color='blue')
axes.plot(subjects, scores2, label='學生2', marker='o', color='red')
axes.set_title('學生成績比較', fontsize=16)#圖表標題
axes.set_xlabel('科目', fontsize=14)#X軸的標題
axes.set_ylabel('分數', fontsize=14)#Y軸的標題

#顯示背景網格
axes.grid(True, linestyle='--', alpha=1,axis='y')#(啟用背景網格,格式虛線,不透明度,僅顯示y軸虛線)

#顯示圖標註解
axes.legend(loc='upper left', fontsize=10,edgecolor='black', facecolor='lightgray',borderpad=1,bbox_to_anchor=(0.80, 0.95))
#圖標註解(位置設定為左上角,圖標大小,圖標框顏色,圖標背景色,圖例內容與邊框的內距（padding）數值越大內部越寬鬆,指定圖例錨點的位置，以圖表左下角為 (0, 0)，右上角為 (1, 1) 的相對座標系統)

#marker上顯示學生分數
for i, score in enumerate(scores1):
    axes.text(subjects[i], score + 1, str(score), ha='center', va='bottom', fontsize=10, color='blue')
for i, score in enumerate(scores2):
    axes.text(subjects[i], score + 1, str(score), ha='center', va='bottom', fontsize=10, color='red')
    #(x軸對齊,y軸位置+1以避免重疊,顯示文字為字串,水平對齊為置中,垂直對齊下方文字,字體大小,文字顏色)

# marker上顯示學生分數,超過圖形範圍,將圖形範圍調整
# 設定y軸範圍(使用原有的最大值和最小值,各增加5)
axes.set_ylim(min(min(scores1), min(scores2)) - 5, max(max(scores1), max(scores2)) + 10)
#設定y軸範圍(挑選最小值(scores1中的最小值),(scores2中的最小值))然後-5的範圍
#設定y軸範圍(挑選最大值(scores1中的最大值),(scores2中的最大值))然後+10的範圍
plt.tight_layout()
#根據目前圖表中的內容，自動調整版面配置，使每個元素都有足夠的空間顯示，避免擠在一起或被擋住。

plt.show()
# Out:
# [78, 80, 92, 75, 85] [90, 75, 98, 65, 75]

# %%
import yfinance as yf

ticker = yf.Ticker("2330.TW")  # 台積電台股代號加上.TW
df = ticker.history(period="max")  # 取得全部歷史資料
print(df.head())
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-01-04 00:00:00+08:00  33.784504  33.784504  33.215107  33.784504
# 2000-01-05 00:00:00+08:00  33.784504  34.543640  33.404845  34.543640
# 2000-01-06 00:00:00+08:00  34.353901  34.543640  33.784504  33.784504
# 2000-01-07 00:00:00+08:00  32.645707  33.215104  32.266048  32.835445
# 2000-01-10 00:00:00+08:00  33.784493  34.163970  33.215096  33.974232
#
#                                  Volume  Dividends  Stock Splits
# Date
# 2000-01-04 00:00:00+08:00  200662336736        0.0           0.0
# 2000-01-05 00:00:00+08:00  402466805912        0.0           0.0
# 2000-01-06 00:00:00+08:00  197545715802        0.0           0.0
# 2000-01-07 00:00:00+08:00  235270344752        0.0           0.0
# 2000-01-10 00:00:00+08:00  276171685539        0.0           0.0

# %%
import yfinance as yf
# 取得 2024 年（1/1 起至 2025/1/1 不含）的台積電交易日資料
df_2024 = ticker.history(start="2024-01-01", end="2025-01-01")
df_2024
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2024-01-02 00:00:00+08:00   575.038964   577.962891   574.064321   577.962891
# 2024-01-03 00:00:00+08:00   569.191054   570.165696   561.393916   563.343201
# 2024-01-04 00:00:00+08:00   565.292480   566.267123   562.368554   565.292480
# 2024-01-05 00:00:00+08:00   563.343205   565.292490   559.444636   561.393921
# 2024-01-08 00:00:00+08:00   567.241849   570.165776   564.317922   568.216492
# ...                                ...          ...          ...          ...
# 2024-12-25 00:00:00+08:00  1080.358973  1080.358973  1070.447423  1075.403198
# 2024-12-26 00:00:00+08:00  1075.403198  1080.358973  1075.403198  1075.403198
# 2024-12-27 00:00:00+08:00  1070.447337  1085.314661  1070.447337  1080.358887
# 2024-12-30 00:00:00+08:00  1080.358887  1085.314661  1075.403112  1080.358887
# 2024-12-31 00:00:00+08:00  1070.447352  1075.403127  1065.491577  1065.491577
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-01-02 00:00:00+08:00  26059058        0.0           0.0
# 2024-01-03 00:00:00+08:00  37106763        0.0           0.0
# 2024-01-04 00:00:00+08:00  15309129        0.0           0.0
# 2024-01-05 00:00:00+08:00  18158971        0.0           0.0
# 2024-01-08 00:00:00+08:00  17761275        0.0           0.0
# ...                             ...        ...           ...
# 2024-12-25 00:00:00+08:00  15481622        0.0           0.0
# 2024-12-26 00:00:00+08:00  14374900        0.0           0.0
# 2024-12-27 00:00:00+08:00  24948385        0.0           0.0
# 2024-12-30 00:00:00+08:00  23954634        0.0           0.0
# 2024-12-31 00:00:00+08:00  28397820        0.0           0.0
#
# [242 rows x 7 columns]

# %%
import yfinance as yf
#台積電(2330.TW),聯電(2303.TW),聯發科(2454.TW),鴻海(2317.TW)
#取得所有 2024 年（1/1 起至 2025/1/1 不含)
tickers = ["2330.TW", "2303.TW", "2454.TW", "2317.TW"]
data = {}
for ticker in tickers:
    stock = yf.Ticker(ticker)
    df = stock.history(start="2024-01-01", end="2025-01-01")
    data[ticker] = df
data["2330.TW"]["Close"]  # 顯示台積電的資料
# Out:
# Date
# 2024-01-02 00:00:00+08:00     577.962891
# 2024-01-03 00:00:00+08:00     563.343201
# 2024-01-04 00:00:00+08:00     565.292480
# 2024-01-05 00:00:00+08:00     561.393921
# 2024-01-08 00:00:00+08:00     568.216492
#                                 ...
# 2024-12-25 00:00:00+08:00    1075.403198
# 2024-12-26 00:00:00+08:00    1075.403198
# 2024-12-27 00:00:00+08:00    1080.358887
# 2024-12-30 00:00:00+08:00    1080.358887
# 2024-12-31 00:00:00+08:00    1065.491577
# Name: Close, Length: 242, dtype: float64

# %%
#data有四檔股票的2024年交易日資料,我需要每一個的收盤價,最後產生一個DataFrame
import pandas as pd
close_prices = {ticker: df["Close"] for ticker, df in data.items()}
close_prices_df = pd.DataFrame(close_prices)
close_prices_df.columns = ["台積電", "聯電", "聯發科", "鴻海"]
close_prices_df
# Out:
#                                    台積電         聯電          聯發科          鴻海
# Date
# 2024-01-02 00:00:00+08:00   577.962891  46.182152   898.153076   98.787247
# 2024-01-03 00:00:00+08:00   563.343201  45.025372   872.517700   98.316833
# 2024-01-04 00:00:00+08:00   565.292480  45.203339   872.141724   97.846420
# 2024-01-05 00:00:00+08:00   561.393921  45.203339   865.563049   97.846420
# 2024-01-08 00:00:00+08:00   568.216492  44.936390   864.623291   95.494339
# ...                                ...        ...          ...         ...
# 2024-12-25 00:00:00+08:00  1075.403198  41.378731  1354.440308  179.964066
# 2024-12-26 00:00:00+08:00  1075.403198  41.049957  1364.046265  180.929031
# 2024-12-27 00:00:00+08:00  1080.358887  40.956017  1373.652222  179.964066
# 2024-12-30 00:00:00+08:00  1080.358887  40.486340  1364.046265  178.516632
# 2024-12-31 00:00:00+08:00  1065.491577  40.439373  1359.243286  177.551682
#
# [242 rows x 4 columns]

# %%
my_dict = {'name': 'Alice', 'age': 25}
for key, value in my_dict.items():
    print(f"Key: {key}, Value: {value}")
# Out:
# Key: name, Value: Alice
# Key: age, Value: 25

# %%
close_prices_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 242 entries, 2024-01-02 00:00:00+08:00 to 2024-12-31 00:00:00+08:00
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   台積電     242 non-null    float64
#  1   聯電      242 non-null    float64
#  2   聯發科     242 non-null    float64
#  3   鴻海      242 non-null    float64
# dtypes: float64(4)
# memory usage: 9.5 KB

# %%
#close_prices_df的索引,只要顯示日期不要顯示時間
#index的data type必需還是datetime格式
close_prices_df.index = pd.to_datetime(close_prices_df.index)

close_prices_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 242 entries, 2024-01-02 00:00:00+08:00 to 2024-12-31 00:00:00+08:00
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   台積電     242 non-null    float64
#  1   聯電      242 non-null    float64
#  2   聯發科     242 non-null    float64
#  3   鴻海      242 non-null    float64
# dtypes: float64(4)
# memory usage: 9.5 KB

# %%
#查詢所有股票的相關係數
close_prices_df.corr()
# Out:
#           台積電        聯電       聯發科        鴻海
# 台積電  1.000000  0.124844  0.883301  0.932589
# 聯電   0.124844  1.000000  0.143217  0.294091
# 聯發科  0.883301  0.143217  1.000000  0.831721
# 鴻海   0.932589  0.294091  0.831721  1.000000

# %%
import wget
import os
#不要重複下載
if not os.path.exists("ChineseFont.ttf"):
    wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont.ttf'

# %%
#已經有中文字型`ChineseFont.ttf`
#接下來要設定字型
#matplotlib預設字型為ChineseFont.ttf
from matplotlib.font_manager import fontManager
import matplotlib as mpl
fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family='ChineseFont')

# %%
#close_prices_df,建立線圖
#使用plt畫圖,(111)
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 8))
for column in close_prices_df.columns:
    plt.plot(close_prices_df.index, close_prices_df[column], label=column)
plt.title('收盤價')
plt.xlabel('日期')
plt.ylabel('價格')
plt.legend()
plt.show()

# %%
#標準寫法
figure = plt.figure(figsize=(16, 8))
ax = figure.add_subplot(111)
for column in close_prices_df.columns:
    ax.plot(close_prices_df.index, close_prices_df[column], label=column)
ax.set_title('收盤價')
ax.set_xlabel('日期')
ax.set_ylabel('價格')
ax.legend()
plt.show()

# %%
close_prices_df.columns
# Out:
# Index(['台積電', '聯電', '聯發科', '鴻海'], dtype='object')

# %%
#close_prices_df,要顯示每日的漲幅金額,例如漲3元,跌-3元
#diff()
daily_returns = close_prices_df.diff()
daily_returns
# Out:
#                                  台積電        聯電        聯發科        鴻海
# Date
# 2024-01-02 00:00:00+08:00        NaN       NaN        NaN       NaN
# 2024-01-03 00:00:00+08:00 -14.619690 -1.156780 -25.635376 -0.470413
# 2024-01-04 00:00:00+08:00   1.949280  0.177967  -0.375977 -0.470413
# 2024-01-05 00:00:00+08:00  -3.898560  0.000000  -6.578674  0.000000
# 2024-01-08 00:00:00+08:00   6.822571 -0.266949  -0.939758 -2.352081
# ...                              ...       ...        ...       ...
# 2024-12-25 00:00:00+08:00   4.955811  0.046967   4.802979  0.964951
# 2024-12-26 00:00:00+08:00   0.000000 -0.328773   9.605957  0.964966
# 2024-12-27 00:00:00+08:00   4.955688 -0.093941   9.605957 -0.964966
# 2024-12-30 00:00:00+08:00   0.000000 -0.469677  -9.605957 -1.447433
# 2024-12-31 00:00:00+08:00 -14.867310 -0.046967  -4.802979 -0.964951
#
# [242 rows x 4 columns]

# %%
#close_prices_df,要顯示每日的漲幅比例,例如漲3%,跌-3%
#pct_change()
daily_return_pct = close_prices_df.pct_change() * 100
daily_return_pct
# Out:
#                                 台積電        聯電       聯發科        鴻海
# Date
# 2024-01-02 00:00:00+08:00       NaN       NaN       NaN       NaN
# 2024-01-03 00:00:00+08:00 -2.529521 -2.504821 -2.854232 -0.476188
# 2024-01-04 00:00:00+08:00  0.346020  0.395260 -0.043091 -0.478467
# 2024-01-05 00:00:00+08:00 -0.689654  0.000000 -0.754313  0.000000
# 2024-01-08 00:00:00+08:00  1.215291 -0.590551 -0.108572 -2.403850
# ...                             ...       ...       ...       ...
# 2024-12-25 00:00:00+08:00  0.462966  0.113633  0.355872  0.539081
# 2024-12-26 00:00:00+08:00  0.000000 -0.794547  0.709220  0.536199
# 2024-12-27 00:00:00+08:00  0.460821 -0.228845  0.704225 -0.533339
# 2024-12-30 00:00:00+08:00  0.000000 -1.146784 -0.699301 -0.804290
# 2024-12-31 00:00:00+08:00 -1.376145 -0.116006 -0.352113 -0.540538
#
# [242 rows x 4 columns]

# %%
#close_prices_df,要顯示每日的漲幅比例,例如漲3%,跌-3%
#pct_change()
daily_return_pct = close_prices_df.pct_change() * 100
#顯示要有`%`符號,最多顯示小數點3位數
daily_return_pct = daily_return_pct.applymap(lambda x: f"{x:.3f}%" if pd.notnull(x) else "-")
daily_return_pct
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16548\2442283864.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   daily_return_pct = daily_return_pct.applymap(lambda x: f"{x:.3f}%" if pd.notnull(x) else "-")
#                                台積電       聯電      聯發科       鴻海
# Date
# 2024-01-02 00:00:00+08:00        -        -        -        -
# 2024-01-03 00:00:00+08:00  -2.530%  -2.505%  -2.854%  -0.476%
# 2024-01-04 00:00:00+08:00   0.346%   0.395%  -0.043%  -0.478%
# 2024-01-05 00:00:00+08:00  -0.690%   0.000%  -0.754%   0.000%
# 2024-01-08 00:00:00+08:00   1.215%  -0.591%  -0.109%  -2.404%
# ...                            ...      ...      ...      ...
# 2024-12-25 00:00:00+08:00   0.463%   0.114%   0.356%   0.539%
# 2024-12-26 00:00:00+08:00   0.000%  -0.795%   0.709%   0.536%
# 2024-12-27 00:00:00+08:00   0.461%  -0.229%   0.704%  -0.533%
# 2024-12-30 00:00:00+08:00   0.000%  -1.147%  -0.699%  -0.804%
# 2024-12-31 00:00:00+08:00  -1.376%  -0.116%  -0.352%  -0.541%
#
# [242 rows x 4 columns]

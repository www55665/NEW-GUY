# %%
import pandas as pd

df = pd.read_csv('交通流量.csv', encoding='utf-8', index_col='交流道')
df
# Out:
#        路線方向     路段         進出口     週六     週日   週2-4
# 交流道
# 基隆端    國1南向  非主線資料          進口  34246  31547  29403
# 基隆     國1南向  非主線資料          出口   9484   8123   9403
# 基隆     國1南向  非主線資料  進口1-尚仁路,基隆   2108   1997   2579
# 基隆     國1南向  非主線資料  進口2-麥金路,金山   6051   5398   5895
# 八堵     國1南向  非主線資料          進口  10785  11990   9027
# ...     ...    ...         ...    ...    ...    ...
# 燕巢系統  國10西向  非主線資料          出口   4612   4647   3906
# 燕巢系統  國10西向  非主線資料     進口1-國3南   6515   8890   6517
# 燕巢系統  國10西向  非主線資料     進口2-國3北  10822  13415  11181
# 嶺口    國10西向  非主線資料          進口   5196   5680   4242
# 旗山端   國10西向  非主線資料          進口  12946  17106  10412
#
# [756 rows x 6 columns]

# %%
#如何透過subscript選取columns
df['路線方向']
df[['路線方向', '進出口']]
# Out:
#        路線方向         進出口
# 交流道
# 基隆端    國1南向          進口
# 基隆     國1南向          出口
# 基隆     國1南向  進口1-尚仁路,基隆
# 基隆     國1南向  進口2-麥金路,金山
# 八堵     國1南向          進口
# ...     ...         ...
# 燕巢系統  國10西向          出口
# 燕巢系統  國10西向     進口1-國3南
# 燕巢系統  國10西向     進口2-國3北
# 嶺口    國10西向          進口
# 旗山端   國10西向          進口
#
# [756 rows x 2 columns]

# %%
#如何透過subscript選取index
df.loc['基隆']
df.loc[['基隆', '台北']]
# Out:
#      路線方向     路段         進出口     週六     週日   週2-4
# 交流道
# 基隆   國1南向  非主線資料          出口   9484   8123   9403
# 基隆   國1南向  非主線資料  進口1-尚仁路,基隆   2108   1997   2579
# 基隆   國1南向  非主線資料  進口2-麥金路,金山   6051   5398   5895
# 基隆   國1北向  非主線資料          出口   9432   8400   9266
# 基隆   國1北向  非主線資料          進口   9232   7718   9173
# 台北   國1南向  非主線資料      出口1-士林  32521  29262  32571
# 台北   國1南向  非主線資料    出口2-台北市區   6587   6238   6576
# 台北   國1南向  非主線資料          進口  23876  21345  23967
# 台北   國1北向  非主線資料          出口  24261  22136  24481
# 台北   國1北向  非主線資料          進口  32383  29404  29985

# %%
#透過值的選取
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 756 entries, 基隆端 to 旗山端
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   路線方向    756 non-null    object
#  1   路段      756 non-null    object
#  2   進出口     756 non-null    object
#  3   週六      756 non-null    object
#  4   週日      756 non-null    object
#  5   週2-4    756 non-null    object
# dtypes: object(6)
# memory usage: 57.5+ KB

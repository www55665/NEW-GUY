# %%
import pandas as pd
#將DataFrame當作資料庫來操作
df = pd.read_csv('world.csv')

# %%
df.head()
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187885 entries, 0 to 187884
# Data columns (total 33 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ID              187885 non-null  int64
#  1   iso_code        187885 non-null  object
#  2   洲名              187885 non-null  object
#  3   國家              187885 non-null  object
#  4   日期              187885 non-null  object
#  5   總確診數            187885 non-null  int64
#  6   新增確診數           187885 non-null  int64
#  7   七天移動平均新增確診數     187885 non-null  float64
#  8   總死亡數            187885 non-null  int64
#  9   新增死亡數           187885 non-null  int64
#  10  七天移動平均新增死亡數     187885 non-null  float64
#  11  每百萬人確診數         187885 non-null  float64
#  12  每百萬人死亡數         187885 non-null  float64
#  13  傳染率             187885 non-null  float64
#  14  新增檢驗件數          187885 non-null  int64
#  15  總檢驗件數           187885 non-null  int64
# ...

# %%
df1 = df[['洲名','國家','日期','總確診數','新增確診數','總人口數','解封指數']]

df1.shape
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187885 entries, 0 to 187884
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   洲名      187885 non-null  object
#  1   國家      187885 non-null  object
#  2   日期      187885 non-null  object
#  3   總確診數    187885 non-null  int64
#  4   新增確診數   187885 non-null  int64
#  5   總人口數    187885 non-null  int64
#  6   解封指數    187885 non-null  float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 10.0+ MB

# %%
df1['日期'] = pd.to_datetime(df1['日期'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14640\433372219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['日期'] = pd.to_datetime(df1['日期'])

# %%
df1.head()
# Out:
#    洲名   國家         日期  總確診數  新增確診數      總人口數     解封指數
# 0  亞洲  阿富汗 2020-02-24     5      5  39835428  99999.0
# 1  亞洲  阿富汗 2020-02-25     5      0  39835428  99999.0
# 2  亞洲  阿富汗 2020-02-26     5      0  39835428  99999.0
# 3  亞洲  阿富汗 2020-02-27     5      0  39835428  99999.0
# 4  亞洲  阿富汗 2020-02-28     5      0  39835428  99999.0

# %%
is_taiwan = df1['國家'] == "台灣"
df_taiwan = df1[is_taiwan]
df_taiwan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 903 entries, 163986 to 164888
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   洲名      903 non-null    object
#  1   國家      903 non-null    object
#  2   日期      903 non-null    datetime64[ns]
#  3   總確診數    903 non-null    int64
#  4   新增確診數   903 non-null    int64
#  5   總人口數    903 non-null    int64
#  6   解封指數    903 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 56.4+ KB

# %%
is_japan = df1['國家'] == "日本"
df_japan = df1[is_japan]
df_japan
# Out:
#        洲名  國家                   日期     總確診數  新增確診數       總人口數     解封指數
# 85626  亞洲  日本  2020-01-22 00:00:00        2      0  126050796  99999.0
# 85627  亞洲  日本  2020-01-23 00:00:00        2      0  126050796  99999.0
# 85628  亞洲  日本  2020-01-24 00:00:00        2      0  126050796  99999.0
# 85629  亞洲  日本  2020-01-25 00:00:00        2      0  126050796  99999.0
# 85630  亞洲  日本  2020-01-26 00:00:00        4      2  126050796  99999.0
# ...    ..  ..                  ...      ...    ...        ...      ...
# 86518  亞洲  日本  2022-07-02 00:00:00  9364954  24875  126050796  99999.0
# 86519  亞洲  日本  2022-07-03 00:00:00  9388222  23268  126050796  99999.0
# 86520  亞洲  日本  2022-07-04 00:00:00  9405007  16785  126050796  99999.0
# 86521  亞洲  日本  2022-07-05 00:00:00  9441171  36164  126050796  99999.0
# 86522  亞洲  日本  2022-07-06 00:00:00  9486965  45794  126050796  99999.0
#
# [897 rows x 7 columns]

# %%
df_taiwan
# Out:
#         洲名  國家         日期     總確診數  新增確診數      總人口數      解封指數
# 163986  亞洲  台灣 2020-01-16        0      0  23855008  99999.00
# 163987  亞洲  台灣 2020-01-17        0      0  23855008  99999.00
# 163988  亞洲  台灣 2020-01-18        0      0  23855008  99999.00
# 163989  亞洲  台灣 2020-01-19        0      0  23855008  99999.00
# 163990  亞洲  台灣 2020-01-20        0      0  23855008  99999.00
# ...     ..  ..        ...      ...    ...       ...       ...
# 164884  亞洲  台灣 2022-07-02  3837856  34807  23855008    258.17
# 164885  亞洲  台灣 2022-07-03  3870528  32672  23855008    260.37
# 164886  亞洲  台灣 2022-07-04  3893643  23115  23855008    261.94
# 164887  亞洲  台灣 2022-07-05  3929627  35984  23855008    264.37
# 164888  亞洲  台灣 2022-07-06  3964188  34561  23855008    266.71
#
# [903 rows x 7 columns]

# %%
df_taiwan[df_taiwan['日期'].dt.year == 2021]
#語法需將資料格式轉換為datatime格式才能使用
# Out:
#         洲名  國家         日期   總確診數  新增確診數      總人口數  解封指數
# 164337  亞洲  台灣 2021-01-01    802      3  23855008  0.19
# 164338  亞洲  台灣 2021-01-02    808      6  23855008  0.19
# 164339  亞洲  台灣 2021-01-03    812      4  23855008  0.19
# 164340  亞洲  台灣 2021-01-04    815      3  23855008  0.18
# 164341  亞洲  台灣 2021-01-05    817      2  23855008  0.18
# ...     ..  ..        ...    ...    ...       ...   ...
# 164697  亞洲  台灣 2021-12-27  16931     16  23855008  0.20
# 164698  亞洲  台灣 2021-12-28  16950     19  23855008  0.20
# 164699  亞洲  台灣 2021-12-29  16964     14  23855008  0.20
# 164700  亞洲  台灣 2021-12-30  16988     24  23855008  0.21
# 164701  亞洲  台灣 2021-12-31  17029     41  23855008  0.21
#
# [365 rows x 7 columns]

# %%
df_taiwan[df_taiwan['日期'].dt.month == 5]
# Out:
#         洲名  國家         日期     總確診數  新增確診數      總人口數    解封指數
# 164092  亞洲  台灣 2020-05-01      429      0  23855008    0.34
# 164093  亞洲  台灣 2020-05-02      432      3  23855008    0.35
# 164094  亞洲  台灣 2020-05-03      436      4  23855008    0.33
# 164095  亞洲  台灣 2020-05-04      438      2  23855008    0.33
# 164096  亞洲  台灣 2020-05-05      438      0  23855008    0.33
# ...     ..  ..        ...      ...    ...       ...     ...
# 164848  亞洲  台灣 2022-05-27  1735067  94796  23855008  116.08
# 164849  亞洲  台灣 2022-05-28  1815703  80636  23855008  121.52
# 164850  亞洲  台灣 2022-05-29  1892272  76569  23855008  126.69
# 164851  亞洲  台灣 2022-05-30  1952355  60083  23855008  130.75
# 164852  亞洲  台灣 2022-05-31  2032983  80628  23855008  136.19
#
# [93 rows x 7 columns]

# %%
df_taiwan_2021_05 = df_taiwan[(df_taiwan['日期'].dt.year == 2021) & (df_taiwan['日期'].dt.month == 5)]

# %%
df_taiwan_2021_05[df_taiwan_2021_05['新增確診數'] >= 300]
# Out:
#         洲名  國家         日期  總確診數  新增確診數      總人口數  解封指數
# 164473  亞洲  台灣 2021-05-17  2017    335  23855008  0.81
# 164477  亞洲  台灣 2021-05-21  3139    314  23855008  1.78
# 164478  亞洲  台灣 2021-05-22  3862    723  23855008  2.42
# 164479  亞洲  台灣 2021-05-23  4322    460  23855008  2.84
# 164480  亞洲  台灣 2021-05-24  4917    595  23855008  3.37
# 164481  亞洲  台灣 2021-05-25  5456    539  23855008  3.85
# 164482  亞洲  台灣 2021-05-26  6091    635  23855008  4.42
# 164483  亞洲  台灣 2021-05-27  6761    670  23855008  5.02
# 164484  亞洲  台灣 2021-05-28  7315    554  23855008  5.53
# 164485  亞洲  台灣 2021-05-29  7806    491  23855008  5.98
# 164486  亞洲  台灣 2021-05-30  8160    354  23855008  6.30
# 164487  亞洲  台灣 2021-05-31  8511    351  23855008  6.62
